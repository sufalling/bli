# %% [markdown]
# # 1 基本数据类型
#
# ## 1.1 基本数据类型介绍
#
# 包括整数（int）、浮点（float）、布尔（Boolean）、字符串（str）
#
# ### 1.1.1 整数（int）
#
# 常用方法
#
# #### abs():返回绝对值

# %%
abs(-10)
# Out:
# 10

# %% [markdown]
# #### pow(base, exp):返回幂
#  $ {base} ^ {exp} $

# %%
pow(2,2)

# %% [markdown]
# ### 1.1.2 浮点（float）

# %% [markdown]
# #### 绝对值

# %% [markdown]
# #### 四舍五入

# %% [markdown]
# ### 1.1.3 字符串（str）

# %% [markdown]
# ### 1.1.4 布尔（Boolean）

# %% [markdown]
# ## 1.2 基本数据类型之间转换
